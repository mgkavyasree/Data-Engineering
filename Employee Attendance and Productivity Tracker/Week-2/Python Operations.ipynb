# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Loading Dataset**

# %%
dfAttendance = pd.read_csv(r"/content/attendance.csv")
dfTasks = pd.read_csv(r"/content/tasks.csv")
dfEmpl = pd.read_csv(r"/content/employees.csv")

# %% [markdown]
# # **Check dataframes by printing**

# %%
dfAttendance.head()
# Out:
#    attendenceID  employeeID        date                  clockIN  \
# 0             1           1  2024-06-01  2024-06-01 09:02:00.000
# 1             2           2  2024-06-01  2024-06-01 08:55:00.000
# 2             3           3  2024-06-01                      NaN
# 3             4           4  2024-06-01  2024-06-01 09:10:00.000
# 4             5           5  2024-06-01  2024-06-01 08:50:00.000
#
#                   clockOUT  isLate  isAbscent
# 0  2024-06-01 17:00:00.000       1          0
# 1  2024-06-01 17:10:00.000       0          0
# 2                      NaN       0          1
# 3  2024-06-01 17:05:00.000       1          0
# 4  2024-06-01 16:45:00.000       0          0

# %%
dfTasks.head()
# Out:
#    taskID  employeeID                   taskName    taskDate  tasksCompeleted
# 0       1           1            API Integration  01-06-2024                5
# 1       2           2  Content Calendar Creation  01-06-2024                3
# 2       3           3              Policy Review  01-06-2024                0
# 3       4           4                CI/CD Setup  01-06-2024                4
# 4       5           5           Invoice Auditing  01-06-2024                6

# %%
dfEmpl.head()
# Out:
#    employeeID           name   department                role  \
# 0           1       John Doe  Engineering  Software Developer
# 1           2     Jane Smith    Marketing  Content Strategist
# 2           3  Alice Johnson           HR          HR Manager
# 3           4      Bob Brown  Engineering     DevOps Engineer
# 4           5      Eva Green      Finance          Accountant
#
#                        email                 hireDate    status
# 0       john.doe@example.com  2023-01-15 00:00:00.000    Active
# 1     jane.smith@example.com  2022-11-20 00:00:00.000    Active
# 2  alice.johnson@example.com  2021-09-10 00:00:00.000    Active
# 3      bob.brown@example.com  2023-05-01 00:00:00.000    Active
# 4      eva.green@example.com  2022-06-30 00:00:00.000  Resigned

# %% [markdown]
# # **Clean missing entries**
#
# *  Only Null values present in attendance we can consider it as absent and drop it

# %%
dfTasks = dfTasks.dropna()
dfAttendance = dfAttendance.dropna()

# %% [markdown]
# # **Calculating workhours, breaktimes and productivity score**

# %%
df = dfAttendance.merge(dfTasks, how="inner", on="employeeID").merge(dfEmpl, how="inner", on="employeeID")

# %%
df["workingHours"] = round(abs((pd.to_datetime(df["clockIN"]) - pd.to_datetime(df["clockOUT"])).dt.total_seconds() / 3600), 2)
df["productivityScore"] = round(df["tasksCompeleted"] / df["workingHours"], 2)
df["breakTimes"] = round(df["workingHours"] / 4)

# %%
df.head()
# Out:
#    attendenceID  employeeID        date                  clockIN  \
# 0             1           1  2024-06-01  2024-06-01 09:02:00.000
# 1             2           2  2024-06-01  2024-06-01 08:55:00.000
# 2             4           4  2024-06-01  2024-06-01 09:10:00.000
# 3             5           5  2024-06-01  2024-06-01 08:50:00.000
#
#                   clockOUT  isLate  isAbscent  taskID  \
# 0  2024-06-01 17:00:00.000       1          0       1
# 1  2024-06-01 17:10:00.000       0          0       2
# 2  2024-06-01 17:05:00.000       1          0       4
# 3  2024-06-01 16:45:00.000       0          0       5
#
#                     taskName    taskDate  tasksCompeleted        name  \
# 0            API Integration  01-06-2024                5    John Doe
# 1  Content Calendar Creation  01-06-2024                3  Jane Smith
# 2                CI/CD Setup  01-06-2024                4   Bob Brown
# 3           Invoice Auditing  01-06-2024                6   Eva Green
#
#     department                role                   email  \
# 0  Engineering  Software Developer    john.doe@example.com
# 1    Marketing  Content Strategist  jane.smith@example.com
# 2  Engineering     DevOps Engineer   bob.brown@example.com
# 3      Finance          Accountant   eva.green@example.com
#
#                   hireDate    status  workingHours  productivityScore  \
# 0  2023-01-15 00:00:00.000    Active          7.97               0.63
# 1  2022-11-20 00:00:00.000    Active          8.25               0.36
# 2  2023-05-01 00:00:00.000    Active          7.92               0.51
# 3  2022-06-30 00:00:00.000  Resigned          7.92               0.76
#
#    breakTimes
# 0         2.0
# 1         2.0
# 2         2.0
# 3         2.0

# %% [markdown]
# # **Finding top and bottom performer**

# %%
summary = df.groupby("employeeID").agg(
    hoursSpent=pd.NamedAgg(column="workingHours", aggfunc="mean"),
    productivityScore=pd.NamedAgg(column="productivityScore", aggfunc="mean"),
    abscentCount=pd.NamedAgg(column="isAbscent", aggfunc="sum")
)

# %%
summary_final = dfEmpl[["employeeID", "name"]].merge(summary, on="employeeID", how="left")

topPerformer = summary_final.sort_values("productivityScore", ascending=False).iloc[0, :].rename("TopPerformer")

bottomPerformer = summary_final.sort_values(["abscentCount", "productivityScore"], ascending=[False, True]).iloc[0, :].rename("BottomPerformer")

# %% [markdown]
# # **Deliverables:-**
# - Cleaned attendance and task dataset
# - Report of top and bottom performer

# %%
# 1. cleaned dataset
dfAttendance.to_csv("cleaned_attendance.csv")
dfTasks.to_csv("cleaned_tasks.csv")

# %%
# 2. report of top and bottom performer
print("-----------------Top performer report----------------------")
print(f"Top performer: {topPerformer.iloc[1]}")
for i, j in topPerformer.items():
  if i != "name":
    print(f"{i}: {j}")
print("-----------------------------------------------------------\n")

print("-----------------Bottom performer report-------------------")
print(f"Bottom performer: {bottomPerformer.iloc[1]}")
for i, j in bottomPerformer.items():
  if i != "name":
    print(f"{i}: {j}")
print("-----------------------------------------------------------\n")
# Out:
# -----------------Top performer report----------------------
# Top performer: Eva Green
# employeeID: 5
# hoursSpent: 7.92
# productivityScore: 0.76
# abscentCount: 0.0
# -----------------------------------------------------------
#
# -----------------Bottom performer report-------------------
# Bottom performer: Jane Smith
# employeeID: 2
# hoursSpent: 8.25
# productivityScore: 0.36
# abscentCount: 0.0
# -----------------------------------------------------------
